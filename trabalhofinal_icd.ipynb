# %% [markdown]
# # Trabalho de Final Introdução a Ciência de Dados

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import math

# %%
df = pd.read_csv('datasets/DataScientist.csv')
df.head()
# Out:
#    Unnamed: 0  index                          Job Title  \
# 0           0      0              Senior Data Scientist
# 1           1      1  Data Scientist, Product Analytics
# 2           2      2               Data Science Manager
# 3           3      3                       Data Analyst
# 4           4      4             Director, Data Science
#
#                 Salary Estimate  \
# 0  $111K-$181K (Glassdoor est.)
# 1  $111K-$181K (Glassdoor est.)
# 2  $111K-$181K (Glassdoor est.)
# 3  $111K-$181K (Glassdoor est.)
# 4  $111K-$181K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5
# 1  At Noom, we use scientifically proven methods ...     4.5
# 2  Decode_M\n\nhttps://www.decode-m.com/\n\nData ...    -1.0
# 3  Sapphire Digital seeks a dynamic and driven mi...     3.4
# 4  Director, Data Science - (200537)\nDescription...     3.4
#
# ...

# %%
print(df.describe())
print(df.shape)
# Out:
#         Unnamed: 0        index       Rating      Founded
# count  3909.000000  3909.000000  3909.000000  3909.000000
# mean   1954.000000  2167.446662     3.283576  1479.154771
# std    1128.575429  1247.657849     1.575749   855.750138
# min       0.000000     0.000000    -1.000000    -1.000000
# 25%     977.000000  1121.000000     3.200000  1625.000000
# 50%    1954.000000  2161.000000     3.700000  1976.000000
# 75%    2931.000000  3249.000000     4.100000  2002.000000
# max    3908.000000  4379.000000     5.000000  2020.000000
# (3909, 17)

# %%
ab = df[['Location','Founded']]
ab = ab[ab["Founded"] != -1]
print(ab)
plt.hist(ab['Founded'],bins = 15,edgecolor = 'k')
plt.show()
# Out:
#            Location  Founded
# 0      New York, NY     2007
# 1      New York, NY     2008
# 3     Lyndhurst, NJ     2019
# 4      New York, NY     2007
# 5      New York, NY     1985
# ...             ...      ...
# 3902   Columbus, OH     2007
# 3903     Dublin, OH     2010
# 3904     Dublin, OH     2011
# 3905   Columbus, OH     2008
# 3906     Dublin, OH     1977
#
# [2932 rows x 2 columns]

# %%
plt.hist(df['Rating'],bins = 15,edgecolor = 'k')
# Out:
# (array([409.,   0.,   0.,   0.,   0.,  10.,  11.,  10.,  72., 177., 653.,
#         956., 774., 531., 306.]),
#  array([-1. , -0.6, -0.2,  0.2,  0.6,  1. ,  1.4,  1.8,  2.2,  2.6,  3. ,
#          3.4,  3.8,  4.2,  4.6,  5. ]),
#  <a list of 15 Patch objects>)

# %%
gb = df.groupby('Salary Estimate')
gb.count()
# Out:
#                                   Unnamed: 0  index  Job Title  \
# Salary Estimate
# $10-$26 Per Hour(Glassdoor est.)           3      3          3
# $100K-$152K (Glassdoor est.)              30     30         30
# $100K-$163K (Glassdoor est.)              30     30         30
# $100K-$172K (Glassdoor est.)              37     37         37
# $102K-$121K (Glassdoor est.)              30     30         30
# ...                                      ...    ...        ...
# $97K-$159K (Glassdoor est.)               32     32         32
# $98K-$152K (Glassdoor est.)               31     31         31
# $98K-$160K (Glassdoor est.)               30     30         30
# $99K-$173K (Glassdoor est.)                6      6          6
# $99K-$174K (Glassdoor est.)               30     30         30
#
#                                   Job Description  Rating  Company Name  \
# Salary Estimate
# $10-$26 Per Hour(Glassdoor est.)                3       3             3
# ...

# %%
sns.set(style = 'ticks')
sns.pairplot(df)
